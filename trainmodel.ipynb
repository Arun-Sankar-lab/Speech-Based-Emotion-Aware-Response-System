# %%
"""import zipfile
import os
import numpy as np
import librosa
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import classification_report
from sklearn.utils import class_weight

EMOTIONS = ['neutral', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

def extract_dataset(zip_path):
    print(f"Extracting {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall('ravdess_data')

    for root, dirs, files in os.walk('ravdess_data'):
        if any(d.startswith('Actor_') for d in dirs):
            print(f" Found audio directory at: {root}")
            return root
    return 'ravdess_data'

def create_emotion_model():
    model = keras.Sequential([
        layers.Input(shape=(40, 100, 3)),
        layers.Conv2D(64, (3, 3), activation='elu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Conv2D(128, (3, 3), activation='elu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Flatten(),
        layers.Dense(256, activation='elu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(len(EMOTIONS), activation='softmax')
    ])

    optimizer = keras.optimizers.Adam(learning_rate=0.0001)

    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
    )
    return model

def extract_features(audio_data, sr=16000):
    try:
        audio_data, _ = librosa.effects.trim(audio_data)
        audio_data = librosa.util.fix_length(audio_data, size=sr * 3)

        mfccs = librosa.feature.mfcc(y=audio_data, sr=sr, n_mfcc=40)

        delta_mfccs = librosa.feature.delta(mfccs)
        delta2_mfccs = librosa.feature.delta(mfccs, order=2)

        features = np.stack([mfccs, delta_mfccs, delta2_mfccs], axis=-1)
        features = (features - np.mean(features)) / (np.std(features) + 1e-6)

        target_length = 100
        if features.shape[1] < target_length:
            features = np.pad(features, ((0, 0), (0, target_length - features.shape[1]), (0, 0)), mode='constant')
        else:
            features = features[:, :target_length, :]

        return features
    except Exception as e:
        print(f"Feature error: {e}")
        return None

def train_emotion_model(train_data_path, model_save_path='emotion_model.keras', epochs=100, batch_size=32):
    X_all, y_all = [], []

    print(f"Loading files from {train_data_path}...")

    for root, _, files in os.walk(train_data_path):
        for file in files:
            if file.endswith('.wav'):
                parts = file.split('-')
                if len(parts) < 3: continue

                emotion_num = int(parts[2])
                if emotion_num <= 2: label = 0
                else: label = emotion_num - 2

                try:
                    audio_data, sr = librosa.load(os.path.join(root, file), sr=16000)
                    features = extract_features(audio_data, sr)
                    if features is not None:
                        X_all.append(features)
                        y_all.append(label)
                except Exception: continue

    X_all = np.array(X_all)
    y_all = np.array(y_all)

    weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_all), y=y_all)
    class_weights = dict(enumerate(weights))

    indices = np.arange(len(X_all))
    np.random.shuffle(indices)
    X_all = X_all[indices]
    y_all = y_all[indices]

    y_all_cat = keras.utils.to_categorical(y_all, len(EMOTIONS))

    model = create_emotion_model()

    callbacks = [
        keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-7, verbose=1),
        keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)
    ]

    print(f"Training on {len(X_all)} samples with 3-channel features...")
    model.fit(
        X_all, y_all_cat,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=0.2,
        shuffle=True,
        class_weight=class_weights,
        callbacks=callbacks
    )

    print("\n--- Final Performance Report ---")
    predictions = model.predict(X_all)
    y_pred_labels = np.argmax(predictions, axis=1)
    print(classification_report(y_all, y_pred_labels, target_names=EMOTIONS))

    model.save(model_save_path)
    return model

if __name__ == "__main__":
    ZIP_FILE_NAME = '/content/Ravdess-20260214T111346Z-1-001.zip'

    if os.path.exists(ZIP_FILE_NAME):
        DATA_PATH = extract_dataset(ZIP_FILE_NAME)
        train_emotion_model(DATA_PATH)
    else:
        print(f"Error: {ZIP_FILE_NAME} not found.")"""
# Out:
# Extracting /content/Ravdess-20260214T111346Z-1-001.zip...
# ✓ Found audio directory at: ravdess_data/Ravdess/audio_speech_actors_01-24
# Loading files from ravdess_data/Ravdess/audio_speech_actors_01-24...
# Training on 1440 samples with 3-channel features...
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 0.2266 - loss: 2.8872 - precision: 0.2489 - recall: 0.1616 - val_accuracy: 0.2188 - val_loss: 2.0465 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3091 - loss: 2.3563 - precision: 0.3450 - recall: 0.2113 - val_accuracy: 0.2118 - val_loss: 2.5559 - val_precision: 0.3090 - val_recall: 0.1910 - learning_rate: 1.0000e-04
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3993 - loss: 1.8691 - precision: 0.4461 - recall: 0.2904 - val_accuracy: 0.2222 - val_loss: 2.9089 - val_precision: 0.2574 - val_recall: 0.2118 - learning_rate: 1.0000e-04
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4293 - loss: 1.7441 - precision: 0.5132 - recall: 0.3339 - val_accuracy: 0.1944 - val_loss: 3.5053 - val_precision: 0.2105 - val_recall: 0.1944 - learning_rate: 1.0000e-04
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4646 - loss: 1.5369 - precision: 0.5576 - recall: 0.3530 - val_accuracy: 0.1979 - val_loss: 3.3975 - val_precision: 0.2121 - val_recall: 0.1944 - learning_rate: 1.0000e-04
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4981 - loss: 1.4368 - precision: 0.5826 - recall: 0.3707 - val_accuracy: 0.2153 - val_loss: 3.0241 - val_precision: 0.2248 - val_recall: 0.2014 - learning_rate: 1.0000e-04
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5465 - loss: 1.3012 - precision: 0.6292 - recall: 0.4295 - val_accuracy: 0.2361 - val_loss: 2.9701 - val_precision: 0.2470 - val_recall: 0.2118 - learning_rate: 1.0000e-04
# Epoch 8/100
# 33/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5579 - loss: 1.1782 - precision: 0.6479 - recall: 0.4724
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5581 - loss: 1.1786 - precision: 0.6479 - recall: 0.4718 - val_accuracy: 0.2604 - val_loss: 2.8802 - val_precision: 0.2612 - val_recall: 0.2222 - learning_rate: 1.0000e-04
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5919 - loss: 1.1460 - precision: 0.7125 - recall: 0.5066 - val_accuracy: 0.2604 - val_loss: 2.9006 - val_precision: 0.2702 - val_recall: 0.2326 - learning_rate: 5.0000e-05
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5774 - loss: 1.1223 - precision: 0.6762 - recall: 0.4874 - val_accuracy: 0.2847 - val_loss: 2.6368 - val_precision: 0.2910 - val_recall: 0.2465 - learning_rate: 5.0000e-05
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6491 - loss: 0.9769 - precision: 0.7519 - recall: 0.5612 - val_accuracy: 0.3160 - val_loss: 2.3532 - val_precision: 0.3154 - val_recall: 0.2639 - learning_rate: 5.0000e-05
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6243 - loss: 0.9904 - precision: 0.7341 - recall: 0.5339 - val_accuracy: 0.3333 - val_loss: 2.3429 - val_precision: 0.3374 - val_recall: 0.2847 - learning_rate: 5.0000e-05
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6977 - loss: 0.8708 - precision: 0.7738 - recall: 0.5944 - val_accuracy: 0.3715 - val_loss: 2.2457 - val_precision: 0.3792 - val_recall: 0.3160 - learning_rate: 5.0000e-05
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6998 - loss: 0.8702 - precision: 0.7944 - recall: 0.5944 - val_accuracy: 0.3958 - val_loss: 1.9685 - val_precision: 0.4359 - val_recall: 0.3542 - learning_rate: 5.0000e-05
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7002 - loss: 0.9025 - precision: 0.7857 - recall: 0.6325 - val_accuracy: 0.4167 - val_loss: 1.8597 - val_precision: 0.4558 - val_recall: 0.3403 - learning_rate: 5.0000e-05
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6914 - loss: 0.8338 - precision: 0.7911 - recall: 0.6083 - val_accuracy: 0.4444 - val_loss: 1.7699 - val_precision: 0.5169 - val_recall: 0.3715 - learning_rate: 5.0000e-05
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6975 - loss: 0.8642 - precision: 0.7879 - recall: 0.5999 - val_accuracy: 0.4201 - val_loss: 1.7848 - val_precision: 0.5172 - val_recall: 0.3646 - learning_rate: 5.0000e-05
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7276 - loss: 0.7459 - precision: 0.7986 - recall: 0.6469 - val_accuracy: 0.4826 - val_loss: 1.6402 - val_precision: 0.5229 - val_recall: 0.3958 - learning_rate: 5.0000e-05
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7530 - loss: 0.6990 - precision: 0.8270 - recall: 0.6755 - val_accuracy: 0.4688 - val_loss: 1.8341 - val_precision: 0.5463 - val_recall: 0.4097 - learning_rate: 5.0000e-05
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7329 - loss: 0.6889 - precision: 0.8234 - recall: 0.6711 - val_accuracy: 0.4653 - val_loss: 1.7458 - val_precision: 0.5324 - val_recall: 0.3993 - learning_rate: 5.0000e-05
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7889 - loss: 0.6196 - precision: 0.8797 - recall: 0.7118 - val_accuracy: 0.4757 - val_loss: 1.7422 - val_precision: 0.5714 - val_recall: 0.4306 - learning_rate: 5.0000e-05
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7857 - loss: 0.5910 - precision: 0.8517 - recall: 0.7082 - val_accuracy: 0.4861 - val_loss: 1.7000 - val_precision: 0.5576 - val_recall: 0.4201 - learning_rate: 5.0000e-05
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7806 - loss: 0.5926 - precision: 0.8526 - recall: 0.7216 - val_accuracy: 0.4722 - val_loss: 1.8677 - val_precision: 0.5146 - val_recall: 0.4271 - learning_rate: 5.0000e-05
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7507 - loss: 0.6443 - precision: 0.8364 - recall: 0.7048 - val_accuracy: 0.4861 - val_loss: 1.7354 - val_precision: 0.5631 - val_recall: 0.4340 - learning_rate: 5.0000e-05
# Epoch 25/100
# 33/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8005 - loss: 0.5678 - precision: 0.8628 - recall: 0.7370
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7984 - loss: 0.5726 - precision: 0.8608 - recall: 0.7346 - val_accuracy: 0.5035 - val_loss: 1.7406 - val_precision: 0.5670 - val_recall: 0.4410 - learning_rate: 5.0000e-05
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8011 - loss: 0.5698 - precision: 0.8649 - recall: 0.7516 - val_accuracy: 0.4931 - val_loss: 1.6674 - val_precision: 0.5556 - val_recall: 0.4340 - learning_rate: 2.5000e-05
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8297 - loss: 0.4911 - precision: 0.8718 - recall: 0.7525 - val_accuracy: 0.4792 - val_loss: 1.7131 - val_precision: 0.5520 - val_recall: 0.4236 - learning_rate: 2.5000e-05
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8081 - loss: 0.5660 - precision: 0.8611 - recall: 0.7518 - val_accuracy: 0.4896 - val_loss: 1.6665 - val_precision: 0.5619 - val_recall: 0.4410 - learning_rate: 2.5000e-05
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8416 - loss: 0.5058 - precision: 0.8864 - recall: 0.7860 - val_accuracy: 0.4931 - val_loss: 1.6013 - val_precision: 0.5650 - val_recall: 0.4375 - learning_rate: 2.5000e-05
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8219 - loss: 0.5193 - precision: 0.8739 - recall: 0.7723 - val_accuracy: 0.4965 - val_loss: 1.6557 - val_precision: 0.5579 - val_recall: 0.4514 - learning_rate: 2.5000e-05
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8650 - loss: 0.3964 - precision: 0.9051 - recall: 0.8049 - val_accuracy: 0.4931 - val_loss: 1.6656 - val_precision: 0.5498 - val_recall: 0.4410 - learning_rate: 2.5000e-05
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8240 - loss: 0.4739 - precision: 0.8773 - recall: 0.7842 - val_accuracy: 0.4931 - val_loss: 1.6630 - val_precision: 0.5609 - val_recall: 0.4479 - learning_rate: 2.5000e-05
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8297 - loss: 0.4832 - precision: 0.8880 - recall: 0.7848 - val_accuracy: 0.5139 - val_loss: 1.5973 - val_precision: 0.5672 - val_recall: 0.4688 - learning_rate: 2.5000e-05
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8290 - loss: 0.4794 - precision: 0.8889 - recall: 0.7864 - val_accuracy: 0.4931 - val_loss: 1.6238 - val_precision: 0.5424 - val_recall: 0.4444 - learning_rate: 2.5000e-05
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8360 - loss: 0.4687 - precision: 0.8797 - recall: 0.7885 - val_accuracy: 0.5035 - val_loss: 1.6981 - val_precision: 0.5481 - val_recall: 0.4549 - learning_rate: 2.5000e-05
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8501 - loss: 0.4425 - precision: 0.8952 - recall: 0.8055 - val_accuracy: 0.5000 - val_loss: 1.6940 - val_precision: 0.5603 - val_recall: 0.4514 - learning_rate: 2.5000e-05
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8424 - loss: 0.4207 - precision: 0.8929 - recall: 0.7990 - val_accuracy: 0.5139 - val_loss: 1.6702 - val_precision: 0.5579 - val_recall: 0.4514 - learning_rate: 2.5000e-05
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8456 - loss: 0.4085 - precision: 0.8818 - recall: 0.7986 - val_accuracy: 0.5174 - val_loss: 1.6384 - val_precision: 0.5708 - val_recall: 0.4618 - learning_rate: 2.5000e-05
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8714 - loss: 0.3843 - precision: 0.9082 - recall: 0.8342 - val_accuracy: 0.5174 - val_loss: 1.6628 - val_precision: 0.5636 - val_recall: 0.4618 - learning_rate: 2.5000e-05
# Epoch 40/100
# 33/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8368 - loss: 0.4178 - precision: 0.8860 - recall: 0.7914
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8379 - loss: 0.4177 - precision: 0.8859 - recall: 0.7923 - val_accuracy: 0.5174 - val_loss: 1.7309 - val_precision: 0.5661 - val_recall: 0.4757 - learning_rate: 2.5000e-05
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8679 - loss: 0.3986 - precision: 0.9036 - recall: 0.8241 - val_accuracy: 0.5278 - val_loss: 1.5940 - val_precision: 0.5745 - val_recall: 0.4688 - learning_rate: 1.2500e-05
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8983 - loss: 0.3417 - precision: 0.9381 - recall: 0.8533 - val_accuracy: 0.5312 - val_loss: 1.5720 - val_precision: 0.5738 - val_recall: 0.4722 - learning_rate: 1.2500e-05
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8805 - loss: 0.3564 - precision: 0.9084 - recall: 0.8364 - val_accuracy: 0.5208 - val_loss: 1.5816 - val_precision: 0.5745 - val_recall: 0.4688 - learning_rate: 1.2500e-05
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8477 - loss: 0.4120 - precision: 0.8924 - recall: 0.8018 - val_accuracy: 0.5208 - val_loss: 1.6188 - val_precision: 0.5661 - val_recall: 0.4757 - learning_rate: 1.2500e-05
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8862 - loss: 0.3432 - precision: 0.9244 - recall: 0.8432 - val_accuracy: 0.5312 - val_loss: 1.6335 - val_precision: 0.5774 - val_recall: 0.4792 - learning_rate: 1.2500e-05
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8643 - loss: 0.3753 - precision: 0.9030 - recall: 0.8239 - val_accuracy: 0.5069 - val_loss: 1.6671 - val_precision: 0.5690 - val_recall: 0.4722 - learning_rate: 1.2500e-05
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8763 - loss: 0.3930 - precision: 0.9193 - recall: 0.8267 - val_accuracy: 0.5208 - val_loss: 1.5593 - val_precision: 0.5787 - val_recall: 0.4722 - learning_rate: 1.2500e-05
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8858 - loss: 0.3199 - precision: 0.9267 - recall: 0.8520 - val_accuracy: 0.5035 - val_loss: 1.5559 - val_precision: 0.5708 - val_recall: 0.4618 - learning_rate: 1.2500e-05
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8718 - loss: 0.3345 - precision: 0.9052 - recall: 0.8239 - val_accuracy: 0.5035 - val_loss: 1.6156 - val_precision: 0.5690 - val_recall: 0.4722 - learning_rate: 1.2500e-05
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8538 - loss: 0.3625 - precision: 0.8999 - recall: 0.8203 - val_accuracy: 0.5174 - val_loss: 1.6193 - val_precision: 0.5678 - val_recall: 0.4653 - learning_rate: 1.2500e-05
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8971 - loss: 0.3026 - precision: 0.9214 - recall: 0.8646 - val_accuracy: 0.5208 - val_loss: 1.6176 - val_precision: 0.5667 - val_recall: 0.4722 - learning_rate: 1.2500e-05
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8764 - loss: 0.3572 - precision: 0.9101 - recall: 0.8305 - val_accuracy: 0.5174 - val_loss: 1.5789 - val_precision: 0.5678 - val_recall: 0.4653 - learning_rate: 1.2500e-05
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8791 - loss: 0.3509 - precision: 0.9226 - recall: 0.8476 - val_accuracy: 0.5174 - val_loss: 1.5785 - val_precision: 0.5592 - val_recall: 0.4757 - learning_rate: 1.2500e-05
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8916 - loss: 0.3352 - precision: 0.9199 - recall: 0.8493 - val_accuracy: 0.5069 - val_loss: 1.5844 - val_precision: 0.5506 - val_recall: 0.4722 - learning_rate: 1.2500e-05
# Epoch 55/100
# 33/36 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9002 - loss: 0.2888 - precision: 0.9281 - recall: 0.8637
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9005 - loss: 0.2897 - precision: 0.9284 - recall: 0.8642 - val_accuracy: 0.5000 - val_loss: 1.6158 - val_precision: 0.5542 - val_recall: 0.4618 - learning_rate: 1.2500e-05
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8775 - loss: 0.3338 - precision: 0.9161 - recall: 0.8325 - val_accuracy: 0.5000 - val_loss: 1.6232 - val_precision: 0.5588 - val_recall: 0.4618 - learning_rate: 6.2500e-06
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8870 - loss: 0.3129 - precision: 0.9174 - recall: 0.8530 - val_accuracy: 0.5000 - val_loss: 1.6422 - val_precision: 0.5514 - val_recall: 0.4653 - learning_rate: 6.2500e-06
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9027 - loss: 0.2943 - precision: 0.9332 - recall: 0.8707 - val_accuracy: 0.5069 - val_loss: 1.6356 - val_precision: 0.5582 - val_recall: 0.4826 - learning_rate: 6.2500e-06
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8840 - loss: 0.3229 - precision: 0.9201 - recall: 0.8539 - val_accuracy: 0.5035 - val_loss: 1.6029 - val_precision: 0.5597 - val_recall: 0.4722 - learning_rate: 6.2500e-06
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8980 - loss: 0.3282 - precision: 0.9317 - recall: 0.8588 - val_accuracy: 0.5104 - val_loss: 1.5994 - val_precision: 0.5610 - val_recall: 0.4792 - learning_rate: 6.2500e-06
# Epoch 61/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8931 - loss: 0.3046 - precision: 0.9228 - recall: 0.8681 - val_accuracy: 0.5104 - val_loss: 1.5939 - val_precision: 0.5528 - val_recall: 0.4722 - learning_rate: 6.2500e-06
# Epoch 62/100
# 33/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8754 - loss: 0.3406 - precision: 0.9111 - recall: 0.8372
# Epoch 62: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8783 - loss: 0.3357 - precision: 0.9132 - recall: 0.8403 - val_accuracy: 0.5000 - val_loss: 1.6095 - val_precision: 0.5466 - val_recall: 0.4688 - learning_rate: 6.2500e-06
# Epoch 63/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8873 - loss: 0.3021 - precision: 0.9277 - recall: 0.8658 - val_accuracy: 0.4931 - val_loss: 1.5989 - val_precision: 0.5514 - val_recall: 0.4653 - learning_rate: 3.1250e-06
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 48.
#
# --- Final Performance Report ---
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#               precision    recall  f1-score   support
#
#      neutral       0.77      0.96      0.85       288
#        happy       0.85      0.88      0.87       192
#          sad       0.73      0.88      0.80       192
#        angry       0.97      0.80      0.88       192
#      fearful       0.88      0.83      0.85       192
#      disgust       0.97      0.68      0.80       192
#    surprised       0.92      0.86      0.89       192
#
#     accuracy                           0.85      1440
#    macro avg       0.87      0.84      0.85      1440
# weighted avg       0.86      0.85      0.85      1440

# %%
def predict_emotion(model, file_path):
    audio_data, sr = librosa.load(file_path, sr=16000)
    features = extract_features(audio_data, sr)

    if features is not None:
        input_data = np.expand_dims(features, axis=0)

        prediction = model.predict(input_data)
        emotion_idx = np.argmax(prediction)
        confidence = np.max(prediction)

        return EMOTIONS[emotion_idx], confidence
    return None, 0

# %%
import zipfile
import os
import numpy as np
import librosa
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import classification_report
from sklearn.utils import class_weight

EMOTIONS = ['neutral', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

def extract_dataset(zip_path):
    print(f"Extracting {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall('aggregated_data')
    return 'aggregated_data'

def get_label_from_file(file_name, root_path):
    fn = file_name.lower()
    path = root_path.lower()

    if 'tess' in path or 'oaf_' in fn or 'yaf_' in fn:
        if 'neutral' in fn: return 0
        if 'happy' in fn: return 1
        if 'sad' in fn: return 2
        if 'angry' in fn: return 3
        if 'fear' in fn: return 4
        if 'disgust' in fn: return 5
        if 'pleasant_surprised' in fn or 'surprise' in fn: return 6

    if fn.startswith('03-') or '-' in fn:
        parts = fn.split('-')
        if len(parts) >= 3:
            num = int(parts[2])
            if num <= 2: return 0
            return num - 2

    if '_ang_' in fn: return 3
    if '_hap_' in fn: return 1
    if '_sad_' in fn: return 2
    if '_fea_' in fn: return 4
    if '_dis_' in fn: return 5
    if '_neu_' in fn: return 0

    if 'savee' in path or fn.startswith('dc_') or fn.startswith('jk_'):
        code = fn.split('_')[1][0] if '_' in fn else fn[0]
        mapping = {'n':0, 'h':1, 's':2, 'a':3, 'f':4, 'd':5, 'u':6}
        return mapping.get(code, None)

    return None

def create_emotion_model():
    model = keras.Sequential([
        layers.Input(shape=(40, 100, 3)),
        layers.Conv2D(64, (3, 3), activation='elu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Conv2D(128, (3, 3), activation='elu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        layers.Conv2D(256, (3, 3), activation='elu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.4),

        layers.Flatten(),
        layers.Dense(512, activation='elu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(len(EMOTIONS), activation='softmax')
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.0001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

def extract_features(audio_data, sr=16000):
    try:
        audio_data, _ = librosa.effects.trim(audio_data)
        audio_data = librosa.util.fix_length(audio_data, size=sr * 3)
        mfccs = librosa.feature.mfcc(y=audio_data, sr=sr, n_mfcc=40)
        delta_mfccs = librosa.feature.delta(mfccs)
        delta2_mfccs = librosa.feature.delta(mfccs, order=2)
        features = np.stack([mfccs, delta_mfccs, delta2_mfccs], axis=-1)
        features = (features - np.mean(features)) / (np.std(features) + 1e-6)

        target_length = 100
        if features.shape[1] < target_length:
            features = np.pad(features, ((0, 0), (0, target_length - features.shape[1]), (0, 0)), mode='constant')
        else:
            features = features[:, :target_length, :]
        return features
    except Exception:
        return None

def train_emotion_model(train_data_path, model_save_path='emotion_model.keras', epochs=100):
    X_all, y_all = [], []
    print("Loading datasets (Crema, Ravdess, Savee, Tess)...")

    for root, _, files in os.walk(train_data_path):
        for file in files:
            if file.endswith('.wav'):
                label = get_label_from_file(file, root)
                if label is not None:
                    try:
                        audio_data, sr = librosa.load(os.path.join(root, file), sr=16000)
                        features = extract_features(audio_data, sr)
                        if features is not None:
                            X_all.append(features)
                            y_all.append(label)
                    except: continue

    X_all, y_all = np.array(X_all), np.array(y_all)

    weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_all), y=y_all)
    class_weights = dict(enumerate(weights))

    indices = np.arange(len(X_all))
    np.random.shuffle(indices)
    X_all, y_all = X_all[indices], y_all[indices]
    y_all_cat = keras.utils.to_categorical(y_all, len(EMOTIONS))

    model = create_emotion_model()
    callbacks = [
        keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1),
        keras.callbacks.EarlyStopping(monitor='val_loss', patience=12, restore_best_weights=True, verbose=1)
    ]

    print(f"Total samples across all datasets: {len(X_all)}")
    model.fit(X_all, y_all_cat, epochs=epochs, batch_size=32, validation_split=0.15,
              shuffle=True, class_weight=class_weights, callbacks=callbacks)

    print("\n--- Consolidated Performance Report ---")
    predictions = model.predict(X_all)
    print(classification_report(y_all, np.argmax(predictions, axis=1), target_names=EMOTIONS))

    model.save(model_save_path)
    return model

if __name__ == "__main__":
    ZIP_NAME = '/content/archive(20)-20260214T120908Z-1-001.zip'
    if os.path.exists(ZIP_NAME):
        path = extract_dataset(ZIP_NAME)
        train_emotion_model(path)
    else:
        print("Zip file not found.")
# Out:
# Extracting /content/archive(20)-20260214T120908Z-1-001.zip...
# Loading datasets (Crema, Ravdess, Savee, Tess)...
# Total samples across all datasets: 11762
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 0.2914 - loss: 2.4026 - val_accuracy: 0.2646 - val_loss: 3.0802 - learning_rate: 1.0000e-04
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4379 - loss: 1.6483 - val_accuracy: 0.3320 - val_loss: 2.2828 - learning_rate: 1.0000e-04
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.4576 - loss: 1.4535 - val_accuracy: 0.4102 - val_loss: 1.9665 - learning_rate: 1.0000e-04
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.4904 - loss: 1.3068 - val_accuracy: 0.3626 - val_loss: 2.5370 - learning_rate: 1.0000e-04
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.5021 - loss: 1.2713 - val_accuracy: 0.4028 - val_loss: 2.1740 - learning_rate: 1.0000e-04
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.5242 - loss: 1.1742 - val_accuracy: 0.4300 - val_loss: 1.9916 - learning_rate: 1.0000e-04
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.5233 - loss: 1.1742 - val_accuracy: 0.4402 - val_loss: 1.9950 - learning_rate: 1.0000e-04
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.5435 - loss: 1.1186 - val_accuracy: 0.4431 - val_loss: 1.8765 - learning_rate: 1.0000e-04
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.5471 - loss: 1.0974 - val_accuracy: 0.4623 - val_loss: 1.8400 - learning_rate: 1.0000e-04
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.5647 - loss: 1.0589 - val_accuracy: 0.4827 - val_loss: 1.7003 - learning_rate: 1.0000e-04
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.5724 - loss: 1.0348 - val_accuracy: 0.4691 - val_loss: 2.0808 - learning_rate: 1.0000e-04
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.5925 - loss: 0.9888 - val_accuracy: 0.4805 - val_loss: 1.8543 - learning_rate: 1.0000e-04
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.5994 - loss: 0.9387 - val_accuracy: 0.4720 - val_loss: 1.7860 - learning_rate: 1.0000e-04
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6148 - loss: 0.9229 - val_accuracy: 0.4924 - val_loss: 1.6474 - learning_rate: 1.0000e-04
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6155 - loss: 0.8929 - val_accuracy: 0.5331 - val_loss: 1.5192 - learning_rate: 1.0000e-04
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6248 - loss: 0.8796 - val_accuracy: 0.5207 - val_loss: 1.5287 - learning_rate: 1.0000e-04
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6307 - loss: 0.8774 - val_accuracy: 0.5309 - val_loss: 1.4820 - learning_rate: 1.0000e-04
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6388 - loss: 0.8424 - val_accuracy: 0.5399 - val_loss: 1.4601 - learning_rate: 1.0000e-04
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6436 - loss: 0.8378 - val_accuracy: 0.5626 - val_loss: 1.4052 - learning_rate: 1.0000e-04
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6522 - loss: 0.8121 - val_accuracy: 0.5598 - val_loss: 1.3544 - learning_rate: 1.0000e-04
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6669 - loss: 0.7693 - val_accuracy: 0.5728 - val_loss: 1.2896 - learning_rate: 1.0000e-04
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6682 - loss: 0.7769 - val_accuracy: 0.5762 - val_loss: 1.2774 - learning_rate: 1.0000e-04
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6849 - loss: 0.7461 - val_accuracy: 0.5847 - val_loss: 1.3087 - learning_rate: 1.0000e-04
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6977 - loss: 0.7138 - val_accuracy: 0.6204 - val_loss: 1.1516 - learning_rate: 1.0000e-04
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6984 - loss: 0.7123 - val_accuracy: 0.5847 - val_loss: 1.2380 - learning_rate: 1.0000e-04
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7172 - loss: 0.6591 - val_accuracy: 0.5955 - val_loss: 1.2361 - learning_rate: 1.0000e-04
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7196 - loss: 0.6672 - val_accuracy: 0.6266 - val_loss: 1.1082 - learning_rate: 1.0000e-04
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7311 - loss: 0.6444 - val_accuracy: 0.6391 - val_loss: 1.1065 - learning_rate: 1.0000e-04
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7324 - loss: 0.6349 - val_accuracy: 0.6368 - val_loss: 1.1032 - learning_rate: 1.0000e-04
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7409 - loss: 0.6113 - val_accuracy: 0.6374 - val_loss: 1.0855 - learning_rate: 1.0000e-04
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7510 - loss: 0.5941 - val_accuracy: 0.6091 - val_loss: 1.1958 - learning_rate: 1.0000e-04
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7574 - loss: 0.5705 - val_accuracy: 0.6380 - val_loss: 1.0848 - learning_rate: 1.0000e-04
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7612 - loss: 0.5600 - val_accuracy: 0.6130 - val_loss: 1.1908 - learning_rate: 1.0000e-04
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7747 - loss: 0.5385 - val_accuracy: 0.6363 - val_loss: 1.0549 - learning_rate: 1.0000e-04
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7893 - loss: 0.5051 - val_accuracy: 0.6544 - val_loss: 1.0127 - learning_rate: 1.0000e-04
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7967 - loss: 0.4856 - val_accuracy: 0.6550 - val_loss: 0.9742 - learning_rate: 1.0000e-04
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7882 - loss: 0.5031 - val_accuracy: 0.6465 - val_loss: 1.0510 - learning_rate: 1.0000e-04
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8114 - loss: 0.4456 - val_accuracy: 0.6425 - val_loss: 1.0715 - learning_rate: 1.0000e-04
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8119 - loss: 0.4580 - val_accuracy: 0.6504 - val_loss: 1.0202 - learning_rate: 1.0000e-04
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8116 - loss: 0.4452 - val_accuracy: 0.6595 - val_loss: 1.0661 - learning_rate: 1.0000e-04
# Epoch 41/100
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8282 - loss: 0.4214
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8282 - loss: 0.4215 - val_accuracy: 0.6459 - val_loss: 1.1322 - learning_rate: 1.0000e-04
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8283 - loss: 0.4105 - val_accuracy: 0.6640 - val_loss: 1.0242 - learning_rate: 5.0000e-05
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8391 - loss: 0.3848 - val_accuracy: 0.6663 - val_loss: 1.0135 - learning_rate: 5.0000e-05
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8410 - loss: 0.3803 - val_accuracy: 0.6584 - val_loss: 1.0325 - learning_rate: 5.0000e-05
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8480 - loss: 0.3535 - val_accuracy: 0.6691 - val_loss: 1.0375 - learning_rate: 5.0000e-05
# Epoch 46/100
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8494 - loss: 0.3704
# Epoch 46: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8494 - loss: 0.3703 - val_accuracy: 0.6663 - val_loss: 1.0463 - learning_rate: 5.0000e-05
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8636 - loss: 0.3476 - val_accuracy: 0.6731 - val_loss: 1.0370 - learning_rate: 2.5000e-05
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8699 - loss: 0.3230 - val_accuracy: 0.6714 - val_loss: 1.0551 - learning_rate: 2.5000e-05
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 36.
#
# --- Consolidated Performance Report ---
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
#               precision    recall  f1-score   support
#
#      neutral       0.91      0.81      0.86      1895
#        happy       0.80      0.89      0.84      1923
#          sad       0.73      0.90      0.81      1983
#        angry       0.98      0.83      0.90      1923
#      fearful       0.80      0.84      0.82      1923
#      disgust       0.91      0.76      0.83      1923
#    surprised       0.84      0.99      0.91       192
#
#     accuracy                           0.84     11762
#    macro avg       0.85      0.86      0.85     11762
# weighted avg       0.85      0.84      0.84     11762

# %%
import librosa
import numpy as np
import tensorflow as tf
from tensorflow import keras
import IPython # Added for IPython.display
from IPython.display import display, Javascript, Audio
from google.colab import output
from base64 import b64decode
from io import BytesIO
from pydub import AudioSegment
import warnings

warnings.filterwarnings("ignore", category=SyntaxWarning)

MODEL_PATH = 'emotion_model.keras'
EMOTIONS = ['neutral', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

try:
    model = keras.models.load_model(MODEL_PATH)
except Exception as e:
    print(f"Failed to load model: {e}. Ensure {MODEL_PATH} exists.")

def extract_features_from_voice(audio_data, sr=16000):
    try:
        audio_data, _ = librosa.effects.trim(audio_data)
        audio_data = librosa.util.fix_length(audio_data, size=sr * 3)

        mfccs = librosa.feature.mfcc(y=audio_data, sr=sr, n_mfcc=40)
        delta_mfccs = librosa.feature.delta(mfccs)
        delta2_mfccs = librosa.feature.delta(mfccs, order=2)

        features = np.stack([mfccs, delta_mfccs, delta2_mfccs], axis=-1)
        features = (features - np.mean(features)) / (np.std(features) + 1e-6)

        if features.shape[1] < 100:
            features = np.pad(features, ((0, 0), (0, 100 - features.shape[1]), (0, 0)), mode='constant')
        else:
            features = features[:, :100, :]

        return np.expand_dims(features, axis=0)
    except Exception as e:
        print(f"Feature Extraction Error: {e}")
        return None

RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time));
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader();
  reader.onloadend = e => resolve(e.srcElement.result);
  reader.readAsDataURL(blob);
});
var record = time => new Promise(async resolve => {
  const stream = await navigator.mediaDevices.getUserMedia({ audio: true });
  const recorder = new MediaRecorder(stream);
  const chunks = [];
  recorder.ondataavailable = e => chunks.push(e.data);
  recorder.start();
  await sleep(time);
  recorder.onstop = async () => {
    const blob = new Blob(chunks);
    const text = await b2text(blob);
    resolve(text);
  };
  recorder.stop();
});
"""

def record_and_predict(seconds=3):
    print(f"Recording for {seconds} seconds... Speak now!")
    display(Javascript(RECORD))
    s = output.eval_js(f'record({seconds*1000})')

    b = b64decode(s.split(',')[1])
    audio = AudioSegment.from_file(BytesIO(b))
    audio.export('test_voice.wav', format='wav')

    data, sr = librosa.load('test_voice.wav', sr=16000)
    features = extract_features_from_voice(data, sr)

    if features is not None:
        prediction = model.predict(features)
        emotion_idx = np.argmax(prediction)
        confidence = np.max(prediction) * 100
        print(f"\nResult: I am {confidence:.1f}% sure you sound **{EMOTIONS[emotion_idx]}**")
        display(Audio('test_voice.wav'))

record_and_predict()
# Out:
# Recording for 3 seconds... Speak now!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
#
# Result: I am 82.5% sure you sound **disgust**
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **Generation**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import librosa
import os
import zipfile
import time

print(f"TensorFlow: {tf.__version__}")
print(f"GPU available: {len(tf.config.list_physical_devices('GPU')) > 0}")

ZIP_PATH          = '/content/archive(20)-20260214T120908Z-1-001.zip'
RAVDESS_PATH      = 'aggregated_data'
EMOTION_MODEL     = '/content/emotion_model.keras'
SAVE_PATH         = 'emotion_tts_gan.keras'

EPOCHS            = 30
BATCH_SIZE        = 16
LEARNING_RATE     = 0.0002
MAX_FILES         = None

SAMPLE_RATE       = 22050
MEL_CHANNELS      = 80
HOP_LENGTH        = 256
WIN_LENGTH        = 1024

EMOTIONS = ['neutral', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

print("Config set")

def extract_dataset(zip_path, extract_to='aggregated_data'):
    if not os.path.exists(zip_path):
        print(f"Zip file not found: {zip_path}")
        return None

    if os.path.exists(extract_to) and len(os.listdir(extract_to)) > 0:
        print(f" '{extract_to}' already exists and is not empty, skipping extraction.")
        return extract_to

    print(f"Extracting {zip_path} → {extract_to} ...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    print(f" Extraction complete: {extract_to}")
    return extract_to

DATA_PATH = extract_dataset(ZIP_PATH, RAVDESS_PATH)
if DATA_PATH is None:
    raise FileNotFoundError(f"Could not find or extract dataset from {ZIP_PATH}")

def get_emotion_embeddings(model_path):
    model = keras.models.load_model(model_path)

    dummy = np.zeros((1, 40, 100, 3), dtype=np.float32)
    _ = model(dummy, training=False)

    output_layer = None
    for layer in reversed(model.layers):
        if isinstance(layer, keras.layers.Dense) and layer.units == 7:
            output_layer = layer
            break

    weights = output_layer.get_weights()[0]
    embeddings = weights.T

    norms = np.linalg.norm(embeddings, axis=1, keepdims=True)
    embeddings = embeddings / (norms + 1e-8)

    print(f"Emotion embeddings: {embeddings.shape}")
    return embeddings

emotion_embeddings = get_emotion_embeddings(EMOTION_MODEL)
EMBED_DIM = emotion_embeddings.shape[1]
print(f" Embedding dim: {EMBED_DIM}")

def get_label_from_file(file_name, root_path):
    fn   = file_name.lower()
    path = root_path.lower()

    if 'tess' in path or 'oaf_' in fn or 'yaf_' in fn:
        if 'neutral'  in fn: return 0
        if 'happy'    in fn: return 1
        if 'sad'      in fn: return 2
        if 'angry'    in fn: return 3
        if 'fear'     in fn: return 4
        if 'disgust'  in fn: return 5
        if 'pleasant_surprised' in fn or 'surprise' in fn: return 6

    if fn.startswith('03-') or '-' in fn:
        parts = fn.split('-')
        if len(parts) >= 3:
            try:
                num = int(parts[2])
                if num <= 2: return 0
                return num - 2
            except ValueError:
                pass

    if '_ang_' in fn: return 3
    if '_hap_' in fn: return 1
    if '_sad_' in fn: return 2
    if '_fea_' in fn: return 4
    if '_dis_' in fn: return 5
    if '_neu_' in fn: return 0

    if 'savee' in path or fn.startswith('dc_') or fn.startswith('jk_'):
        code    = fn.split('_')[1][0] if '_' in fn else fn[0]
        mapping = {'n': 0, 'h': 1, 's': 2, 'a': 3, 'f': 4, 'd': 5, 'u': 6}
        return mapping.get(code, None)

    return None

print("Multi-dataset label function ready (RAVDESS, TESS, CREMA-D, SAVEE)")

def audio_to_mel(audio, sr):
    mel = librosa.feature.melspectrogram(
        y=audio, sr=sr,
        n_mels=MEL_CHANNELS,
        hop_length=HOP_LENGTH,
        win_length=WIN_LENGTH,
        fmax=8000
    )
    mel_db   = librosa.power_to_db(mel, ref=np.max)
    mel_norm = (mel_db - mel_db.mean()) / (mel_db.std() + 1e-6)
    return mel_norm

def load_dataset(data_path, max_files=None):
    mels, emotions, embeddings_list = [], [], []
    count      = 0
    skipped    = 0

    for root, _, files in os.walk(data_path):
        for fname in files:
            if not fname.endswith('.wav'):
                continue

            emotion_idx = get_label_from_file(fname, root)
            if emotion_idx is None:
                skipped += 1
                continue

            try:
                fpath = os.path.join(root, fname)
                audio, sr = librosa.load(fpath, sr=SAMPLE_RATE)

                audio, _  = librosa.effects.trim(audio)
                audio     = librosa.util.fix_length(audio, size=SAMPLE_RATE * 3)

                mel = audio_to_mel(audio, SAMPLE_RATE)
                T = 100
                if mel.shape[1] < T:
                    mel = np.pad(mel, ((0, 0), (0, T - mel.shape[1])))
                else:
                    mel = mel[:, :T]

                mels.append(mel.astype(np.float32))
                emotions.append(emotion_idx)
                embeddings_list.append(
                    emotion_embeddings[emotion_idx].astype(np.float32)
                )

                count += 1
                if count % 200 == 0:
                    print(f"  Loaded {count} files...")
                if max_files and count >= max_files:
                    break

            except Exception:
                skipped += 1
                continue

        if max_files and count >= max_files:
            break

    print(f"\nTotal loaded : {count} files")
    print(f"Skipped      : {skipped} files (unrecognized format)")
    print(f"\n  Per emotion:")
    for i, name in enumerate(EMOTIONS):
        c = emotions.count(i)
        if c > 0:
            print(f"    {name:10s}: {c}")

    return (np.array(mels),
            np.array(emotions),
            np.array(embeddings_list))

print("Loading all datasets...")
mels, emotion_labels, embed_data = load_dataset(DATA_PATH, MAX_FILES)
print(f"\nDataset ready: mels={mels.shape}, embeddings={embed_data.shape}")

def build_conditioner(embed_dim):
    mel_input   = keras.Input(shape=(MEL_CHANNELS, None), name='mel')
    embed_input = keras.Input(shape=(embed_dim,),          name='embed')

    params = keras.layers.Dense(MEL_CHANNELS * 2, activation='tanh')(embed_input)
    scale  = keras.ops.expand_dims(params[:, :MEL_CHANNELS], axis=-1)
    bias   = keras.ops.expand_dims(params[:,  MEL_CHANNELS:], axis=-1)

    out = mel_input * (1.0 + scale) + bias
    return keras.Model(inputs=[mel_input, embed_input], outputs=out,
                       name='Conditioner')

def build_vocoder():
    mel_input = keras.Input(shape=(MEL_CHANNELS, None), name='mel')
    x = keras.layers.Lambda(lambda t: keras.ops.transpose(t, [0,2,1]))(mel_input)
    x = keras.layers.Conv1D(128, 7, padding='same')(x)

    ch = 128
    for stride, ksize in [(8,16),(8,16),(2,4),(2,4)]:
        x  = keras.layers.LeakyReLU(0.1)(x)
        x  = keras.layers.Conv1DTranspose(ch//2, ksize, strides=stride, padding='same')(x)
        ch //= 2
        branches = []
        for kernel in [3, 7, 11]:
            r = x
            for dil in [1, 3, 5]:
                r = keras.layers.LeakyReLU(0.1)(r)
                r = keras.layers.Conv1D(ch, kernel, padding='causal', dilation_rate=dil)(r)
                r = r + x
            branches.append(r)
        x = keras.layers.Average()(branches)

    x = keras.layers.LeakyReLU(0.1)(x)
    x = keras.layers.Conv1D(1, 7, padding='same', activation='tanh')(x)
    x = keras.layers.Lambda(lambda t: keras.ops.squeeze(t, axis=-1))(x)
    return keras.Model(inputs=mel_input, outputs=x, name='HiFiGAN')

conditioner = build_conditioner(EMBED_DIM)
vocoder     = build_vocoder()

conditioner.summary()
vocoder.summary()

optimizer = keras.optimizers.Adam(LEARNING_RATE)

@tf.function
def train_step(mel_batch, embed_batch):
    with tf.GradientTape() as tape:
        conditioned = conditioner([mel_batch, embed_batch], training=True)

        waveform = vocoder(conditioned, training=True)

        waveform_3d = tf.expand_dims(waveform, axis=-1)  # (B, T, 1)
        waveform_t  = tf.transpose(waveform_3d, [0,2,1]) # (B, 1, T)

        emotion_loss = tf.reduce_mean(tf.abs(conditioned - mel_batch))

        expected_len = mel_batch.shape[2] * HOP_LENGTH if mel_batch.shape[2] else 100 * HOP_LENGTH
        actual_len   = tf.shape(waveform)[1]
        shape_loss   = tf.cast(tf.abs(actual_len - expected_len), tf.float32) / float(expected_len)

        total_loss = emotion_loss + 0.1 * shape_loss

    trainable_vars = conditioner.trainable_variables + vocoder.trainable_variables
    grads = tape.gradient(total_loss, trainable_vars)
    optimizer.apply_gradients(zip(grads, trainable_vars))

    return total_loss, emotion_loss

def train_tts_gan():
    print("="*60)
    print("Training TTS GAN")
    print("="*60)
    print(f"Samples: {len(mels)} | Epochs: {EPOCHS} | Batch: {BATCH_SIZE}\n")

    n = len(mels)
    steps_per_epoch = n // BATCH_SIZE

    for epoch in range(EPOCHS):
        idx = np.random.permutation(n)
        mels_s   = mels[idx]
        embeds_s = embed_data[idx]

        epoch_loss = 0.0
        t0 = time.time()

        for step in range(steps_per_epoch):
            s = step * BATCH_SIZE
            e = s + BATCH_SIZE

            mel_batch   = tf.constant(mels_s[s:e],   dtype=tf.float32)
            embed_batch = tf.constant(embeds_s[s:e],  dtype=tf.float32)

            loss, em_loss = train_step(mel_batch, embed_batch)
            epoch_loss   += float(loss)

        avg_loss = epoch_loss / steps_per_epoch
        elapsed  = time.time() - t0
        print(f"Epoch {epoch+1:3d}/{EPOCHS} | Loss: {avg_loss:.4f} | Time: {elapsed:.1f}s")

        if (epoch + 1) % 10 == 0:
            conditioner.save_weights(SAVE_PATH + '_conditioner')
            vocoder.save_weights(SAVE_PATH + '_vocoder')
            print(f"Checkpoint saved at epoch {epoch+1}")

    conditioner.save_weights(SAVE_PATH + '_conditioner')
    vocoder.save_weights(SAVE_PATH + '_vocoder')
    print(f"\nTraining complete!")
    print(f"Conditioner saved: {SAVE_PATH}_conditioner")
    print(f"Vocoder saved:     {SAVE_PATH}_vocoder")
    print(f"\nNow run emotion_tts.py — GAN conditioning will be active!")

train_tts_gan()
# Out:
# TensorFlow: 2.19.0
# GPU available: True
# ✓ Config set
# Extracting /content/archive(20)-20260214T120908Z-1-001.zip → aggregated_data ...
# ✓ Extraction complete: aggregated_data
# Emotion embeddings: (7, 512)
#  Embedding dim: 512
# Multi-dataset label function ready (RAVDESS, TESS, CREMA-D, SAVEE)
# Loading all datasets...
#   Loaded 200 files...
#   Loaded 400 files...
#   Loaded 600 files...
#   Loaded 800 files...
#   Loaded 1000 files...
#   Loaded 1200 files...
#   Loaded 1400 files...
#   Loaded 1600 files...
#   Loaded 1800 files...
#   Loaded 2000 files...
#   Loaded 2200 files...
#   Loaded 2400 files...
#   Loaded 2600 files...
#   Loaded 2800 files...
#   Loaded 3000 files...
#   Loaded 3200 files...
#   Loaded 3400 files...
#   Loaded 3600 files...
#   Loaded 3800 files...
#   Loaded 4000 files...
#   Loaded 4200 files...
#   Loaded 4400 files...
#   Loaded 4600 files...
#   Loaded 4800 files...
#   Loaded 5000 files...
#   Loaded 5200 files...
#   Loaded 5400 files...
#   Loaded 5600 files...
#   Loaded 5800 files...
#   Loaded 6000 files...
#   Loaded 6200 files...
#   Loaded 6400 files...
#   Loaded 6600 files...
#   Loaded 6800 files...
#   Loaded 7000 files...
#   Loaded 7200 files...
#   Loaded 7400 files...
#   Loaded 7600 files...
#   Loaded 7800 files...
#   Loaded 8000 files...
#   Loaded 8200 files...
#   Loaded 8400 files...
#   Loaded 8600 files...
#   Loaded 8800 files...
#   Loaded 9000 files...
#   Loaded 9200 files...
#   Loaded 9400 files...
#   Loaded 9600 files...
#   Loaded 9800 files...
#   Loaded 10000 files...
#   Loaded 10200 files...
#   Loaded 10400 files...
#   Loaded 10600 files...
#   Loaded 10800 files...
#   Loaded 11000 files...
#   Loaded 11200 files...
#   Loaded 11400 files...
#   Loaded 11600 files...
#
# Total loaded : 11762 files
# Skipped      : 400 files (unrecognized format)
#
#   Per emotion:
#     neutral   : 1895
#     happy     : 1923
#     sad       : 1983
#     angry     : 1923
#     fearful   : 1923
#     disgust   : 1923
#     surprised : 192
#
# Dataset ready: mels=(11762, 80, 100), embeddings=(11762, 512)
# Model: "Conditioner"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ embed (InputLayer)  │ (None, 512)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 160)       │     82,080 │ embed[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 80)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims         │ (None, 80, 1)     │          0 │ get_item[0][0]    │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mel (InputLayer)    │ (None, 80, None)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 80, 1)     │          0 │ expand_dims[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 80)        │          0 │ dense[0][0]       │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 80, None)  │          0 │ mel[0][0],        │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims_1       │ (None, 80, 1)     │          0 │ get_item_1[0][0]  │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 80, None)  │          0 │ multiply[0][0],   │
# │                     │                   │            │ expand_dims_1[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 82,080 (320.62 KB)
#  Trainable params: 82,080 (320.62 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "HiFiGAN"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ mel (InputLayer)    │ (None, 80, None)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, None, 80)  │          0 │ mel[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, None, 128) │     71,808 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, None, 128) │          0 │ conv1d[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose    │ (None, None, 64)  │    131,136 │ leaky_re_lu[0][0] │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, None, 64)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, None, 64)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, None, 64)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, None, 64)  │     12,352 │ leaky_re_lu_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, None, 64)  │     28,736 │ leaky_re_lu_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, None, 64)  │     45,120 │ leaky_re_lu_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, None, 64)  │          0 │ conv1d_1[0][0],   │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, None, 64)  │          0 │ conv1d_4[0][0],   │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, None, 64)  │          0 │ conv1d_7[0][0],   │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, None, 64)  │          0 │ add_2[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, None, 64)  │          0 │ add_5[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, None, 64)  │          0 │ add_8[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, None, 64)  │     12,352 │ leaky_re_lu_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, None, 64)  │     28,736 │ leaky_re_lu_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, None, 64)  │     45,120 │ leaky_re_lu_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, None, 64)  │          0 │ conv1d_2[0][0],   │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, None, 64)  │          0 │ conv1d_5[0][0],   │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, None, 64)  │          0 │ conv1d_8[0][0],   │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, None, 64)  │          0 │ add_3[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, None, 64)  │          0 │ add_6[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, None, 64)  │          0 │ add_9[0][0]       │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, None, 64)  │     12,352 │ leaky_re_lu_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, None, 64)  │     28,736 │ leaky_re_lu_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, None, 64)  │     45,120 │ leaky_re_lu_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, None, 64)  │          0 │ conv1d_3[0][0],   │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, None, 64)  │          0 │ conv1d_6[0][0],   │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, None, 64)  │          0 │ conv1d_9[0][0],   │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average (Average)   │ (None, None, 64)  │          0 │ add_4[0][0],      │
# │                     │                   │            │ add_7[0][0],      │
# │                     │                   │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, None, 64)  │          0 │ average[0][0]     │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_1  │ (None, None, 32)  │     32,800 │ leaky_re_lu_10[0… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, None, 32)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, None, 32)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, None, 32)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, None, 32)  │      3,104 │ leaky_re_lu_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, None, 32)  │      7,200 │ leaky_re_lu_14[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, None, 32)  │     11,296 │ leaky_re_lu_17[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, None, 32)  │          0 │ conv1d_10[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, None, 32)  │          0 │ conv1d_13[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, None, 32)  │          0 │ conv1d_16[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, None, 32)  │          0 │ add_11[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, None, 32)  │          0 │ add_14[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_18      │ (None, None, 32)  │          0 │ add_17[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, None, 32)  │      3,104 │ leaky_re_lu_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, None, 32)  │      7,200 │ leaky_re_lu_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, None, 32)  │     11,296 │ leaky_re_lu_18[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, None, 32)  │          0 │ conv1d_11[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, None, 32)  │          0 │ conv1d_14[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, None, 32)  │          0 │ conv1d_17[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, None, 32)  │          0 │ add_12[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, None, 32)  │          0 │ add_15[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_19      │ (None, None, 32)  │          0 │ add_18[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, None, 32)  │      3,104 │ leaky_re_lu_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, None, 32)  │      7,200 │ leaky_re_lu_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, None, 32)  │     11,296 │ leaky_re_lu_19[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, None, 32)  │          0 │ conv1d_12[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, None, 32)  │          0 │ conv1d_15[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, None, 32)  │          0 │ conv1d_18[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_1 (Average) │ (None, None, 32)  │          0 │ add_13[0][0],     │
# │                     │                   │            │ add_16[0][0],     │
# │                     │                   │            │ add_19[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_20      │ (None, None, 32)  │          0 │ average_1[0][0]   │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_2  │ (None, None, 16)  │      2,064 │ leaky_re_lu_20[0… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_21      │ (None, None, 16)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_24      │ (None, None, 16)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_27      │ (None, None, 16)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, None, 16)  │        784 │ leaky_re_lu_21[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_22 (Conv1D)  │ (None, None, 16)  │      1,808 │ leaky_re_lu_24[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_25 (Conv1D)  │ (None, None, 16)  │      2,832 │ leaky_re_lu_27[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, None, 16)  │          0 │ conv1d_19[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, None, 16)  │          0 │ conv1d_22[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, None, 16)  │          0 │ conv1d_25[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_22      │ (None, None, 16)  │          0 │ add_20[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_25      │ (None, None, 16)  │          0 │ add_23[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_28      │ (None, None, 16)  │          0 │ add_26[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, None, 16)  │        784 │ leaky_re_lu_22[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_23 (Conv1D)  │ (None, None, 16)  │      1,808 │ leaky_re_lu_25[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_26 (Conv1D)  │ (None, None, 16)  │      2,832 │ leaky_re_lu_28[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, None, 16)  │          0 │ conv1d_20[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, None, 16)  │          0 │ conv1d_23[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, None, 16)  │          0 │ conv1d_26[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_23      │ (None, None, 16)  │          0 │ add_21[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_26      │ (None, None, 16)  │          0 │ add_24[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_29      │ (None, None, 16)  │          0 │ add_27[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_21 (Conv1D)  │ (None, None, 16)  │        784 │ leaky_re_lu_23[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_24 (Conv1D)  │ (None, None, 16)  │      1,808 │ leaky_re_lu_26[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_27 (Conv1D)  │ (None, None, 16)  │      2,832 │ leaky_re_lu_29[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, None, 16)  │          0 │ conv1d_21[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, None, 16)  │          0 │ conv1d_24[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, None, 16)  │          0 │ conv1d_27[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_2 (Average) │ (None, None, 16)  │          0 │ add_22[0][0],     │
# │                     │                   │            │ add_25[0][0],     │
# │                     │                   │            │ add_28[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_30      │ (None, None, 16)  │          0 │ average_2[0][0]   │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_3  │ (None, None, 8)   │        520 │ leaky_re_lu_30[0… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_31      │ (None, None, 8)   │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_34      │ (None, None, 8)   │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_37      │ (None, None, 8)   │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_28 (Conv1D)  │ (None, None, 8)   │        200 │ leaky_re_lu_31[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_31 (Conv1D)  │ (None, None, 8)   │        456 │ leaky_re_lu_34[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_34 (Conv1D)  │ (None, None, 8)   │        712 │ leaky_re_lu_37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, None, 8)   │          0 │ conv1d_28[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_32 (Add)        │ (None, None, 8)   │          0 │ conv1d_31[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_35 (Add)        │ (None, None, 8)   │          0 │ conv1d_34[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_32      │ (None, None, 8)   │          0 │ add_29[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_35      │ (None, None, 8)   │          0 │ add_32[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_38      │ (None, None, 8)   │          0 │ add_35[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_29 (Conv1D)  │ (None, None, 8)   │        200 │ leaky_re_lu_32[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_32 (Conv1D)  │ (None, None, 8)   │        456 │ leaky_re_lu_35[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_35 (Conv1D)  │ (None, None, 8)   │        712 │ leaky_re_lu_38[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_30 (Add)        │ (None, None, 8)   │          0 │ conv1d_29[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_33 (Add)        │ (None, None, 8)   │          0 │ conv1d_32[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_36 (Add)        │ (None, None, 8)   │          0 │ conv1d_35[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_33      │ (None, None, 8)   │          0 │ add_30[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_36      │ (None, None, 8)   │          0 │ add_33[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_39      │ (None, None, 8)   │          0 │ add_36[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_30 (Conv1D)  │ (None, None, 8)   │        200 │ leaky_re_lu_33[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_33 (Conv1D)  │ (None, None, 8)   │        456 │ leaky_re_lu_36[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_36 (Conv1D)  │ (None, None, 8)   │        712 │ leaky_re_lu_39[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_31 (Add)        │ (None, None, 8)   │          0 │ conv1d_30[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_34 (Add)        │ (None, None, 8)   │          0 │ conv1d_33[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_37 (Add)        │ (None, None, 8)   │          0 │ conv1d_36[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_3 (Average) │ (None, None, 8)   │          0 │ add_31[0][0],     │
# │                     │                   │            │ add_34[0][0],     │
# │                     │                   │            │ add_37[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_40      │ (None, None, 8)   │          0 │ average_3[0][0]   │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_37 (Conv1D)  │ (None, None, 1)   │         57 │ leaky_re_lu_40[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, None)      │          0 │ conv1d_37[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 582,185 (2.22 MB)
#  Trainable params: 582,185 (2.22 MB)
#  Non-trainable params: 0 (0.00 B)
# ============================================================
# Training TTS GAN
# ============================================================
# Samples: 11762 | Epochs: 30 | Batch: 16
# /usr/local/lib/python3.12/dist-packages/keras/src/optimizers/base_optimizer.py:855: UserWarning: Gradients do not exist for variables ['conv1d/kernel', 'conv1d/bias', 'conv1d_transpose/kernel', 'conv1d_transpose/bias', 'conv1d_1/kernel', 'conv1d_1/bias', 'conv1d_4/kernel', 'conv1d_4/bias', 'conv1d_7/kernel', 'conv1d_7/bias', 'conv1d_2/kernel', 'conv1d_2/bias', 'conv1d_5/kernel', 'conv1d_5/bias', 'conv1d_8/kernel', 'conv1d_8/bias', 'conv1d_3/kernel', 'conv1d_3/bias', 'conv1d_6/kernel', 'conv1d_6/bias', 'conv1d_9/kernel', 'conv1d_9/bias', 'conv1d_transpose_1/kernel', 'conv1d_transpose_1/bias', 'conv1d_10/kernel', 'conv1d_10/bias', 'conv1d_13/kernel', 'conv1d_13/bias', 'conv1d_16/kernel', 'conv1d_16/bias', 'conv1d_11/kernel', 'conv1d_11/bias', 'conv1d_14/kernel', 'conv1d_14/bias', 'conv1d_17/kernel', 'conv1d_17/bias', 'conv1d_12/kernel', 'conv1d_12/bias', 'conv1d_15/kernel', 'conv1d_15/bias', 'conv1d_18/kernel', 'conv1d_18/bias', 'conv1d_transpose_2/kernel', 'conv1d_transpose_2/bias', 'conv1d_19/kernel', 'conv1d_19/bias', 'conv1d_22/kernel', 'conv1d_22/bias', 'conv1d_25/kernel', 'conv1d_25/bias', 'conv1d_20/kernel', 'conv1d_20/bias', 'conv1d_23/kernel', 'conv1d_23/bias', 'conv1d_26/kernel', 'conv1d_26/bias', 'conv1d_21/kernel', 'conv1d_21/bias', 'conv1d_24/kernel', 'conv1d_24/bias', 'conv1d_27/kernel', 'conv1d_27/bias', 'conv1d_transpose_3/kernel', 'conv1d_transpose_3/bias', 'conv1d_28/kernel', 'conv1d_28/bias', 'conv1d_31/kernel', 'conv1d_31/bias', 'conv1d_34/kernel', 'conv1d_34/bias', 'conv1d_29/kernel', 'conv1d_29/bias', 'conv1d_32/kernel', 'conv1d_32/bias', 'conv1d_35/kernel', 'conv1d_35/bias', 'conv1d_30/kernel', 'conv1d_30/bias', 'conv1d_33/kernel', 'conv1d_33/bias', 'conv1d_36/kernel', 'conv1d_36/bias', 'conv1d_37/kernel', 'conv1d_37/bias'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# Epoch   1/30 | Loss: 0.0028 | Time: 6.9s
# Epoch   2/30 | Loss: 0.0006 | Time: 2.1s
# Epoch   3/30 | Loss: 0.0006 | Time: 1.6s
# Epoch   4/30 | Loss: 0.0006 | Time: 1.7s
# Epoch   5/30 | Loss: 0.0006 | Time: 1.6s
# Epoch   6/30 | Loss: 0.0006 | Time: 1.6s
# Epoch   7/30 | Loss: 0.0006 | Time: 1.6s
# Epoch   8/30 | Loss: 0.0006 | Time: 1.8s
# Epoch   9/30 | Loss: 0.0006 | Time: 1.9s
# Epoch  10/30 | Loss: 0.0006 | Time: 1.6s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1978978249.py in <cell line: 0>()
#     372     print(f"\nNow run emotion_tts.py — GAN conditioning will be active!")
#     373
# --> 374 train_tts_gan()
#
# /tmp/ipython-input-1978978249.py in train_tts_gan()
#     360         # Save checkpoint every 10 epochs
#     361         if (epoch + 1) % 10 == 0:
# --> 362             conditioner.save_weights(SAVE_PATH + '_conditioner')
#     363             vocoder.save_weights(SAVE_PATH + '_vocoder')
#     364             print(f"Checkpoint saved at epoch {epoch+1}")
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in save_weights(model, filepath, overwrite, max_shard_size, **kwargs)
#     225     filepath_str = str(filepath)
#     226     if max_shard_size is None and not filepath_str.endswith(".weights.h5"):
# --> 227         raise ValueError(
#     228             "The filename must end in `.weights.h5`. "
#     229             f"Received: filepath={filepath_str}"
#
# ValueError: The filename must end in `.weights.h5`. Received: filepath=emotion_tts_gan.keras_conditioner

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import librosa
import os
import time

print(f"TensorFlow: {tf.__version__}")
print(f"GPU available: {len(tf.config.list_physical_devices('GPU')) > 0}")

RAVDESS_PATH      = '/content/aggregated_data'
EMOTION_MODEL     = '/content/emotion_model.keras'
SAVE_PATH         = 'emotion_tts_gan'

EPOCHS            = 30
BATCH_SIZE        = 16
LEARNING_RATE     = 0.0002
MAX_FILES         = None


SAMPLE_RATE       = 22050
MEL_CHANNELS      = 80
HOP_LENGTH        = 256
WIN_LENGTH        = 1024

EMOTIONS = ['neutral', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

print(" Config set")


if not os.path.exists(RAVDESS_PATH):
    raise FileNotFoundError(f"Folder '{RAVDESS_PATH}' not found! "
                            f"Make sure your files are extracted there.")

DATA_PATH = RAVDESS_PATH
print(f" Using dataset folder: {os.path.abspath(DATA_PATH)}")


def get_emotion_embeddings(model_path):
    model = keras.models.load_model(model_path)

    dummy = np.zeros((1, 40, 100, 3), dtype=np.float32)
    _ = model(dummy, training=False)

    output_layer = None
    for layer in reversed(model.layers):
        if isinstance(layer, keras.layers.Dense) and layer.units == 7:
            output_layer = layer
            break

    weights = output_layer.get_weights()[0]
    embeddings = weights.T

    norms = np.linalg.norm(embeddings, axis=1, keepdims=True)
    embeddings = embeddings / (norms + 1e-8)

    print(f" Emotion embeddings: {embeddings.shape}")
    return embeddings

emotion_embeddings = get_emotion_embeddings(EMOTION_MODEL)
EMBED_DIM = emotion_embeddings.shape[1]
print(f" Embedding dim: {EMBED_DIM}")


def get_label_from_file(file_name, root_path):
    fn   = file_name.lower()
    path = root_path.lower()

    if 'tess' in path or 'oaf_' in fn or 'yaf_' in fn:
        if 'neutral'  in fn: return 0
        if 'happy'    in fn: return 1
        if 'sad'      in fn: return 2
        if 'angry'    in fn: return 3
        if 'fear'     in fn: return 4
        if 'disgust'  in fn: return 5
        if 'pleasant_surprised' in fn or 'surprise' in fn: return 6

    if fn.startswith('03-') or '-' in fn:
        parts = fn.split('-')
        if len(parts) >= 3:
            try:
                num = int(parts[2])
                if num <= 2: return 0
                return num - 2
            except ValueError:
                pass

    if '_ang_' in fn: return 3
    if '_hap_' in fn: return 1
    if '_sad_' in fn: return 2
    if '_fea_' in fn: return 4
    if '_dis_' in fn: return 5
    if '_neu_' in fn: return 0

    if 'savee' in path or fn.startswith('dc_') or fn.startswith('jk_'):
        code    = fn.split('_')[1][0] if '_' in fn else fn[0]
        mapping = {'n': 0, 'h': 1, 's': 2, 'a': 3, 'f': 4, 'd': 5, 'u': 6}
        return mapping.get(code, None)

    return None

print(" Multi-dataset label function ready (RAVDESS, TESS, CREMA-D, SAVEE)")

def audio_to_mel(audio, sr):
    mel = librosa.feature.melspectrogram(
        y=audio, sr=sr,
        n_mels=MEL_CHANNELS,
        hop_length=HOP_LENGTH,
        win_length=WIN_LENGTH,
        fmax=8000
    )
    mel_db   = librosa.power_to_db(mel, ref=np.max)
    mel_norm = (mel_db - mel_db.mean()) / (mel_db.std() + 1e-6)
    return mel_norm  # shape: (80, T)

def load_dataset(data_path, max_files=None):
    mels, emotions, embeddings_list = [], [], []
    count      = 0
    skipped    = 0

    for root, _, files in os.walk(data_path):
        for fname in files:
            if not fname.endswith('.wav'):
                continue

            emotion_idx = get_label_from_file(fname, root)
            if emotion_idx is None:
                skipped += 1
                continue

            try:
                fpath = os.path.join(root, fname)
                audio, sr = librosa.load(fpath, sr=SAMPLE_RATE)

                audio, _  = librosa.effects.trim(audio)
                audio     = librosa.util.fix_length(audio, size=SAMPLE_RATE * 3)

                mel = audio_to_mel(audio, SAMPLE_RATE)

                T = 100
                if mel.shape[1] < T:
                    mel = np.pad(mel, ((0, 0), (0, T - mel.shape[1])))
                else:
                    mel = mel[:, :T]

                mels.append(mel.astype(np.float32))
                emotions.append(emotion_idx)
                embeddings_list.append(
                    emotion_embeddings[emotion_idx].astype(np.float32)
                )

                count += 1
                if count % 200 == 0:
                    print(f"  Loaded {count} files...")
                if max_files and count >= max_files:
                    break

            except Exception:
                skipped += 1
                continue

        if max_files and count >= max_files:
            break

    print(f"\nTotal loaded : {count} files")
    print(f"  Skipped      : {skipped} files (unrecognized format)")
    print(f"\n  Per emotion:")
    for i, name in enumerate(EMOTIONS):
        c = emotions.count(i)
        if c > 0:
            print(f"    {name:10s}: {c}")

    return (np.array(mels),
            np.array(emotions),
            np.array(embeddings_list))

print("Loading all datasets...")
mels, emotion_labels, embed_data = load_dataset(DATA_PATH, MAX_FILES)
print(f"\n✓ Dataset ready: mels={mels.shape}, embeddings={embed_data.shape}")

def build_conditioner(embed_dim):
    mel_input   = keras.Input(shape=(MEL_CHANNELS, None), name='mel')
    embed_input = keras.Input(shape=(embed_dim,),          name='embed')

    params = keras.layers.Dense(MEL_CHANNELS * 2, activation='tanh')(embed_input)
    scale  = keras.ops.expand_dims(params[:, :MEL_CHANNELS], axis=-1)
    bias   = keras.ops.expand_dims(params[:,  MEL_CHANNELS:], axis=-1)

    out = mel_input * (1.0 + scale) + bias
    return keras.Model(inputs=[mel_input, embed_input], outputs=out,
                       name='Conditioner')

def build_vocoder():
    mel_input = keras.Input(shape=(MEL_CHANNELS, None), name='mel')
    x = keras.layers.Lambda(lambda t: keras.ops.transpose(t, [0,2,1]))(mel_input)
    x = keras.layers.Conv1D(128, 7, padding='same')(x)

    ch = 128
    for stride, ksize in [(8,16),(8,16),(2,4),(2,4)]:
        x  = keras.layers.LeakyReLU(0.1)(x)
        x  = keras.layers.Conv1DTranspose(ch//2, ksize, strides=stride, padding='same')(x)
        ch //= 2
        branches = []
        for kernel in [3, 7, 11]:
            r = x
            for dil in [1, 3, 5]:
                r = keras.layers.LeakyReLU(0.1)(r)
                r = keras.layers.Conv1D(ch, kernel, padding='causal', dilation_rate=dil)(r)
                r = r + x
            branches.append(r)
        x = keras.layers.Average()(branches)

    x = keras.layers.LeakyReLU(0.1)(x)
    x = keras.layers.Conv1D(1, 7, padding='same', activation='tanh')(x)
    x = keras.layers.Lambda(lambda t: keras.ops.squeeze(t, axis=-1))(x)
    return keras.Model(inputs=mel_input, outputs=x, name='HiFiGAN')

conditioner = build_conditioner(EMBED_DIM)
vocoder     = build_vocoder()

conditioner.summary()
vocoder.summary()

optimizer = keras.optimizers.Adam(LEARNING_RATE)

@tf.function
def train_step(mel_batch, embed_batch):
    with tf.GradientTape() as tape:

        conditioned_mel = conditioner([mel_batch, embed_batch], training=True)

        waveform = vocoder(conditioned_mel, training=True)

        waveform_2d = tf.expand_dims(waveform, axis=-1)

        target_len  = tf.shape(mel_batch)[2]
        waveform_ds = tf.image.resize(
            tf.expand_dims(waveform_2d, 1),
            [1, target_len]
        )
        waveform_ds = tf.squeeze(waveform_ds, axis=[1, 3])
        waveform_ds = tf.expand_dims(waveform_ds, axis=1)

        waveform_mel = tf.tile(waveform_ds, [1, MEL_CHANNELS, 1])

        conditioner_loss = tf.reduce_mean(tf.abs(conditioned_mel - mel_batch))

        vocoder_loss = tf.reduce_mean(tf.abs(waveform_mel - conditioned_mel))

        total_loss = conditioner_loss + vocoder_loss
    trainable_vars = (conditioner.trainable_variables +
                      vocoder.trainable_variables)
    grads = tape.gradient(total_loss, trainable_vars)

    valid = [(g, v) for g, v in zip(grads, trainable_vars) if g is not None]
    if valid:
        optimizer.apply_gradients(valid)

    return total_loss, conditioner_loss, vocoder_loss

def train_tts_gan():
    print("="*60)
    print("Training TTS GAN")
    print("="*60)
    print(f"Samples: {len(mels)} | Epochs: {EPOCHS} | Batch: {BATCH_SIZE}\n")

    n = len(mels)
    steps_per_epoch = n // BATCH_SIZE

    for epoch in range(EPOCHS):
        idx = np.random.permutation(n)
        mels_s   = mels[idx]
        embeds_s = embed_data[idx]

        epoch_loss = 0.0
        t0 = time.time()

        for step in range(steps_per_epoch):
            s = step * BATCH_SIZE
            e = s + BATCH_SIZE

            mel_batch   = tf.constant(mels_s[s:e],   dtype=tf.float32)
            embed_batch = tf.constant(embeds_s[s:e],  dtype=tf.float32)

            loss, c_loss, v_loss = train_step(mel_batch, embed_batch)
            epoch_loss          += float(loss)

        avg_loss = epoch_loss / steps_per_epoch
        elapsed  = time.time() - t0
        print(f"Epoch {epoch+1:3d}/{EPOCHS} | Loss: {avg_loss:.4f} "
              f"(cond: {float(c_loss):.4f}, voc: {float(v_loss):.4f}) | Time: {elapsed:.1f}s")

        if (epoch + 1) % 10 == 0:
            conditioner.save_weights(SAVE_PATH + '_conditioner.weights.h5')
            vocoder.save_weights(SAVE_PATH + '_vocoder.weights.h5')
            print(f"Checkpoint saved at epoch {epoch+1}")

    conditioner.save_weights(SAVE_PATH + '_conditioner.weights.h5')
    vocoder.save_weights(SAVE_PATH + '_vocoder.weights.h5')
    print(f"\n Training complete!")
    print(f" Conditioner saved: {SAVE_PATH}_conditioner.weights.h5")
    print(f" Vocoder saved:     {SAVE_PATH}_vocoder.weights.h5")
    print(f"\nNow run emotion_tts.py — GAN conditioning will be active!")

train_tts_gan()
# Out:
# TensorFlow: 2.19.0
# GPU available: True
# ✓ Config set
# ✓ Using dataset folder: /content/aggregated_data
# ✓ Emotion embeddings: (7, 512)
# ✓ Embedding dim: 512
# ✓ Multi-dataset label function ready (RAVDESS, TESS, CREMA-D, SAVEE)
# Loading all datasets...
#   Loaded 200 files...
#   Loaded 400 files...
#   Loaded 600 files...
#   Loaded 800 files...
#   Loaded 1000 files...
#   Loaded 1200 files...
#   Loaded 1400 files...
#   Loaded 1600 files...
#   Loaded 1800 files...
#   Loaded 2000 files...
#   Loaded 2200 files...
#   Loaded 2400 files...
#   Loaded 2600 files...
#   Loaded 2800 files...
#   Loaded 3000 files...
#   Loaded 3200 files...
#   Loaded 3400 files...
#   Loaded 3600 files...
#   Loaded 3800 files...
#   Loaded 4000 files...
#   Loaded 4200 files...
#   Loaded 4400 files...
#   Loaded 4600 files...
#   Loaded 4800 files...
#   Loaded 5000 files...
#   Loaded 5200 files...
#   Loaded 5400 files...
#   Loaded 5600 files...
#   Loaded 5800 files...
#   Loaded 6000 files...
#   Loaded 6200 files...
#   Loaded 6400 files...
#   Loaded 6600 files...
#   Loaded 6800 files...
#   Loaded 7000 files...
#   Loaded 7200 files...
#   Loaded 7400 files...
#   Loaded 7600 files...
#   Loaded 7800 files...
#   Loaded 8000 files...
#   Loaded 8200 files...
#   Loaded 8400 files...
#   Loaded 8600 files...
#   Loaded 8800 files...
#   Loaded 9000 files...
#   Loaded 9200 files...
#   Loaded 9400 files...
#   Loaded 9600 files...
#   Loaded 9800 files...
#   Loaded 10000 files...
#   Loaded 10200 files...
#   Loaded 10400 files...
#   Loaded 10600 files...
#   Loaded 10800 files...
#   Loaded 11000 files...
#   Loaded 11200 files...
#   Loaded 11400 files...
#   Loaded 11600 files...
#
# ✓ Total loaded : 11762 files
#   Skipped      : 400 files (unrecognized format)
#
#   Per emotion:
#     neutral   : 1895
#     happy     : 1923
#     sad       : 1983
#     angry     : 1923
#     fearful   : 1923
#     disgust   : 1923
#     surprised : 192
#
# ✓ Dataset ready: mels=(11762, 80, 100), embeddings=(11762, 512)
# Model: "Conditioner"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ embed (InputLayer)  │ (None, 512)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 160)       │     82,080 │ embed[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 80)        │          0 │ dense_1[0][0]     │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims_2       │ (None, 80, 1)     │          0 │ get_item_2[0][0]  │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mel (InputLayer)    │ (None, 80, None)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_38 (Add)        │ (None, 80, 1)     │          0 │ expand_dims_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, 80)        │          0 │ dense_1[0][0]     │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 80, None)  │          0 │ mel[0][0],        │
# │ (Multiply)          │                   │            │ add_38[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims_3       │ (None, 80, 1)     │          0 │ get_item_3[0][0]  │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_39 (Add)        │ (None, 80, None)  │          0 │ multiply_1[0][0], │
# │                     │                   │            │ expand_dims_3[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 82,080 (320.62 KB)
#  Trainable params: 82,080 (320.62 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "HiFiGAN"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ mel (InputLayer)    │ (None, 80, None)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, None, 80)  │          0 │ mel[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_38 (Conv1D)  │ (None, None, 128) │     71,808 │ lambda_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_41      │ (None, None, 128) │          0 │ conv1d_38[0][0]   │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_4  │ (None, None, 64)  │    131,136 │ leaky_re_lu_41[0… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_42      │ (None, None, 64)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_45      │ (None, None, 64)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_48      │ (None, None, 64)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_39 (Conv1D)  │ (None, None, 64)  │     12,352 │ leaky_re_lu_42[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_42 (Conv1D)  │ (None, None, 64)  │     28,736 │ leaky_re_lu_45[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_45 (Conv1D)  │ (None, None, 64)  │     45,120 │ leaky_re_lu_48[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_40 (Add)        │ (None, None, 64)  │          0 │ conv1d_39[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_43 (Add)        │ (None, None, 64)  │          0 │ conv1d_42[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_46 (Add)        │ (None, None, 64)  │          0 │ conv1d_45[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_43      │ (None, None, 64)  │          0 │ add_40[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_46      │ (None, None, 64)  │          0 │ add_43[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_49      │ (None, None, 64)  │          0 │ add_46[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_40 (Conv1D)  │ (None, None, 64)  │     12,352 │ leaky_re_lu_43[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_43 (Conv1D)  │ (None, None, 64)  │     28,736 │ leaky_re_lu_46[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_46 (Conv1D)  │ (None, None, 64)  │     45,120 │ leaky_re_lu_49[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_41 (Add)        │ (None, None, 64)  │          0 │ conv1d_40[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_44 (Add)        │ (None, None, 64)  │          0 │ conv1d_43[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_47 (Add)        │ (None, None, 64)  │          0 │ conv1d_46[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_44      │ (None, None, 64)  │          0 │ add_41[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_47      │ (None, None, 64)  │          0 │ add_44[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_50      │ (None, None, 64)  │          0 │ add_47[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_41 (Conv1D)  │ (None, None, 64)  │     12,352 │ leaky_re_lu_44[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_44 (Conv1D)  │ (None, None, 64)  │     28,736 │ leaky_re_lu_47[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_47 (Conv1D)  │ (None, None, 64)  │     45,120 │ leaky_re_lu_50[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_42 (Add)        │ (None, None, 64)  │          0 │ conv1d_41[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_45 (Add)        │ (None, None, 64)  │          0 │ conv1d_44[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_48 (Add)        │ (None, None, 64)  │          0 │ conv1d_47[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_4 (Average) │ (None, None, 64)  │          0 │ add_42[0][0],     │
# │                     │                   │            │ add_45[0][0],     │
# │                     │                   │            │ add_48[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_51      │ (None, None, 64)  │          0 │ average_4[0][0]   │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_5  │ (None, None, 32)  │     32,800 │ leaky_re_lu_51[0… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_52      │ (None, None, 32)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_55      │ (None, None, 32)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_58      │ (None, None, 32)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_48 (Conv1D)  │ (None, None, 32)  │      3,104 │ leaky_re_lu_52[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_51 (Conv1D)  │ (None, None, 32)  │      7,200 │ leaky_re_lu_55[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_54 (Conv1D)  │ (None, None, 32)  │     11,296 │ leaky_re_lu_58[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_49 (Add)        │ (None, None, 32)  │          0 │ conv1d_48[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_52 (Add)        │ (None, None, 32)  │          0 │ conv1d_51[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_55 (Add)        │ (None, None, 32)  │          0 │ conv1d_54[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_53      │ (None, None, 32)  │          0 │ add_49[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_56      │ (None, None, 32)  │          0 │ add_52[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_59      │ (None, None, 32)  │          0 │ add_55[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_49 (Conv1D)  │ (None, None, 32)  │      3,104 │ leaky_re_lu_53[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_52 (Conv1D)  │ (None, None, 32)  │      7,200 │ leaky_re_lu_56[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_55 (Conv1D)  │ (None, None, 32)  │     11,296 │ leaky_re_lu_59[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_50 (Add)        │ (None, None, 32)  │          0 │ conv1d_49[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_53 (Add)        │ (None, None, 32)  │          0 │ conv1d_52[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_56 (Add)        │ (None, None, 32)  │          0 │ conv1d_55[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_54      │ (None, None, 32)  │          0 │ add_50[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_57      │ (None, None, 32)  │          0 │ add_53[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_60      │ (None, None, 32)  │          0 │ add_56[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_50 (Conv1D)  │ (None, None, 32)  │      3,104 │ leaky_re_lu_54[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_53 (Conv1D)  │ (None, None, 32)  │      7,200 │ leaky_re_lu_57[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_56 (Conv1D)  │ (None, None, 32)  │     11,296 │ leaky_re_lu_60[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_51 (Add)        │ (None, None, 32)  │          0 │ conv1d_50[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_54 (Add)        │ (None, None, 32)  │          0 │ conv1d_53[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_57 (Add)        │ (None, None, 32)  │          0 │ conv1d_56[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_5 (Average) │ (None, None, 32)  │          0 │ add_51[0][0],     │
# │                     │                   │            │ add_54[0][0],     │
# │                     │                   │            │ add_57[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_61      │ (None, None, 32)  │          0 │ average_5[0][0]   │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_6  │ (None, None, 16)  │      2,064 │ leaky_re_lu_61[0… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_62      │ (None, None, 16)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_65      │ (None, None, 16)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_68      │ (None, None, 16)  │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_57 (Conv1D)  │ (None, None, 16)  │        784 │ leaky_re_lu_62[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_60 (Conv1D)  │ (None, None, 16)  │      1,808 │ leaky_re_lu_65[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_63 (Conv1D)  │ (None, None, 16)  │      2,832 │ leaky_re_lu_68[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_58 (Add)        │ (None, None, 16)  │          0 │ conv1d_57[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_61 (Add)        │ (None, None, 16)  │          0 │ conv1d_60[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_64 (Add)        │ (None, None, 16)  │          0 │ conv1d_63[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_63      │ (None, None, 16)  │          0 │ add_58[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_66      │ (None, None, 16)  │          0 │ add_61[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_69      │ (None, None, 16)  │          0 │ add_64[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_58 (Conv1D)  │ (None, None, 16)  │        784 │ leaky_re_lu_63[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_61 (Conv1D)  │ (None, None, 16)  │      1,808 │ leaky_re_lu_66[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_64 (Conv1D)  │ (None, None, 16)  │      2,832 │ leaky_re_lu_69[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_59 (Add)        │ (None, None, 16)  │          0 │ conv1d_58[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_62 (Add)        │ (None, None, 16)  │          0 │ conv1d_61[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_65 (Add)        │ (None, None, 16)  │          0 │ conv1d_64[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_64      │ (None, None, 16)  │          0 │ add_59[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_67      │ (None, None, 16)  │          0 │ add_62[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_70      │ (None, None, 16)  │          0 │ add_65[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_59 (Conv1D)  │ (None, None, 16)  │        784 │ leaky_re_lu_64[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_62 (Conv1D)  │ (None, None, 16)  │      1,808 │ leaky_re_lu_67[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_65 (Conv1D)  │ (None, None, 16)  │      2,832 │ leaky_re_lu_70[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_60 (Add)        │ (None, None, 16)  │          0 │ conv1d_59[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_63 (Add)        │ (None, None, 16)  │          0 │ conv1d_62[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_66 (Add)        │ (None, None, 16)  │          0 │ conv1d_65[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_6 (Average) │ (None, None, 16)  │          0 │ add_60[0][0],     │
# │                     │                   │            │ add_63[0][0],     │
# │                     │                   │            │ add_66[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_71      │ (None, None, 16)  │          0 │ average_6[0][0]   │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_7  │ (None, None, 8)   │        520 │ leaky_re_lu_71[0… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_72      │ (None, None, 8)   │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_75      │ (None, None, 8)   │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_78      │ (None, None, 8)   │          0 │ conv1d_transpose… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_66 (Conv1D)  │ (None, None, 8)   │        200 │ leaky_re_lu_72[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_69 (Conv1D)  │ (None, None, 8)   │        456 │ leaky_re_lu_75[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_72 (Conv1D)  │ (None, None, 8)   │        712 │ leaky_re_lu_78[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_67 (Add)        │ (None, None, 8)   │          0 │ conv1d_66[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_70 (Add)        │ (None, None, 8)   │          0 │ conv1d_69[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_73 (Add)        │ (None, None, 8)   │          0 │ conv1d_72[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_73      │ (None, None, 8)   │          0 │ add_67[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_76      │ (None, None, 8)   │          0 │ add_70[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_79      │ (None, None, 8)   │          0 │ add_73[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_67 (Conv1D)  │ (None, None, 8)   │        200 │ leaky_re_lu_73[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_70 (Conv1D)  │ (None, None, 8)   │        456 │ leaky_re_lu_76[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_73 (Conv1D)  │ (None, None, 8)   │        712 │ leaky_re_lu_79[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_68 (Add)        │ (None, None, 8)   │          0 │ conv1d_67[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_71 (Add)        │ (None, None, 8)   │          0 │ conv1d_70[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_74 (Add)        │ (None, None, 8)   │          0 │ conv1d_73[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_74      │ (None, None, 8)   │          0 │ add_68[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_77      │ (None, None, 8)   │          0 │ add_71[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_80      │ (None, None, 8)   │          0 │ add_74[0][0]      │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_68 (Conv1D)  │ (None, None, 8)   │        200 │ leaky_re_lu_74[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_71 (Conv1D)  │ (None, None, 8)   │        456 │ leaky_re_lu_77[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_74 (Conv1D)  │ (None, None, 8)   │        712 │ leaky_re_lu_80[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_69 (Add)        │ (None, None, 8)   │          0 │ conv1d_68[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_72 (Add)        │ (None, None, 8)   │          0 │ conv1d_71[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_75 (Add)        │ (None, None, 8)   │          0 │ conv1d_74[0][0],  │
# │                     │                   │            │ conv1d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_7 (Average) │ (None, None, 8)   │          0 │ add_69[0][0],     │
# │                     │                   │            │ add_72[0][0],     │
# │                     │                   │            │ add_75[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_81      │ (None, None, 8)   │          0 │ average_7[0][0]   │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_75 (Conv1D)  │ (None, None, 1)   │         57 │ leaky_re_lu_81[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, None)      │          0 │ conv1d_75[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 582,185 (2.22 MB)
#  Trainable params: 582,185 (2.22 MB)
#  Non-trainable params: 0 (0.00 B)
# ============================================================
# Training TTS GAN
# ============================================================
# Samples: 11762 | Epochs: 30 | Batch: 16
#
# Epoch   1/30 | Loss: 0.5247 (cond: 0.0020, voc: 0.4866) | Time: 132.2s
# Epoch   2/30 | Loss: 0.5165 (cond: 0.0021, voc: 0.4773) | Time: 114.7s
# Epoch   3/30 | Loss: 0.5156 (cond: 0.0022, voc: 0.5372) | Time: 115.3s
# Epoch   4/30 | Loss: 0.5151 (cond: 0.0022, voc: 0.5008) | Time: 115.0s
# Epoch   5/30 | Loss: 0.5147 (cond: 0.0019, voc: 0.5690) | Time: 115.2s
# Epoch   6/30 | Loss: 0.5146 (cond: 0.0018, voc: 0.5202) | Time: 114.8s
# Epoch   7/30 | Loss: 0.5146 (cond: 0.0024, voc: 0.5024) | Time: 114.7s
# Epoch   8/30 | Loss: 0.5144 (cond: 0.0023, voc: 0.5505) | Time: 115.0s
# Epoch   9/30 | Loss: 0.5144 (cond: 0.0023, voc: 0.5642) | Time: 114.9s
# Epoch  10/30 | Loss: 0.5142 (cond: 0.0024, voc: 0.5338) | Time: 114.8s
#   ✓ Checkpoint saved at epoch 10
# Epoch  11/30 | Loss: 0.5142 (cond: 0.0022, voc: 0.5144) | Time: 114.8s
# Epoch  12/30 | Loss: 0.5141 (cond: 0.0026, voc: 0.5224) | Time: 114.4s
# Epoch  13/30 | Loss: 0.5141 (cond: 0.0022, voc: 0.5341) | Time: 114.9s
# Epoch  14/30 | Loss: 0.5142 (cond: 0.0021, voc: 0.4923) | Time: 114.7s
# Epoch  15/30 | Loss: 0.5140 (cond: 0.0026, voc: 0.5069) | Time: 114.5s
# Epoch  16/30 | Loss: 0.5140 (cond: 0.0026, voc: 0.5123) | Time: 114.9s
# Epoch  17/30 | Loss: 0.5139 (cond: 0.0027, voc: 0.5313) | Time: 114.5s
# Epoch  18/30 | Loss: 0.5139 (cond: 0.0019, voc: 0.5204) | Time: 114.6s
# Epoch  19/30 | Loss: 0.5140 (cond: 0.0020, voc: 0.4943) | Time: 115.1s
# Epoch  20/30 | Loss: 0.5139 (cond: 0.0023, voc: 0.5102) | Time: 115.1s
#   ✓ Checkpoint saved at epoch 20
# Epoch  21/30 | Loss: 0.5139 (cond: 0.0024, voc: 0.5491) | Time: 114.8s
# Epoch  22/30 | Loss: 0.5139 (cond: 0.0022, voc: 0.5000) | Time: 115.1s
# Epoch  23/30 | Loss: 0.5139 (cond: 0.0028, voc: 0.5394) | Time: 114.6s
# Epoch  24/30 | Loss: 0.5138 (cond: 0.0020, voc: 0.5075) | Time: 114.4s
# Epoch  25/30 | Loss: 0.5137 (cond: 0.0020, voc: 0.5260) | Time: 114.2s
# Epoch  26/30 | Loss: 0.5137 (cond: 0.0021, voc: 0.4603) | Time: 114.6s
# Epoch  27/30 | Loss: 0.5137 (cond: 0.0023, voc: 0.5549) | Time: 114.7s
# Epoch  28/30 | Loss: 0.5137 (cond: 0.0020, voc: 0.5190) | Time: 114.5s
# Epoch  29/30 | Loss: 0.5137 (cond: 0.0019, voc: 0.4714) | Time: 114.6s
# Epoch  30/30 | Loss: 0.5136 (cond: 0.0021, voc: 0.5325) | Time: 114.6s
#   ✓ Checkpoint saved at epoch 30
#
# ✓ Training complete!
# ✓ Conditioner saved: emotion_tts_gan_conditioner.weights.h5
# ✓ Vocoder saved:     emotion_tts_gan_vocoder.weights.h5
#
# Now run emotion_tts.py — GAN conditioning will be active!
